# %% [markdown]
# ### CASE STUDY

# %%
#Importing libraries
import pandas as pd
import numpy as np
import os

# %%
print(os.getcwd())
# Out:
# /home/leda/Projects/case_study

# %%
#Importing the dataset
df = pd.read_stata("BSE_2010.dta", convert_categoricals=False)

# %%
df.head(10)
# Out:
#     Unqid  Country  zgor  zq88  zq89  zq90  zq91_1  zq91_2  zq101   eq1  ...  \
# 0  100011        1     7     1    31     1       9     4.0      8  10.0  ...
# 1  100013        1     3     2    49     6       1     NaN      3   NaN  ...
# 2  100014        1     3     2    33     1       4     2.0      8  10.0  ...
# 3  100015        1     3     2    37     1       2     0.0      8  10.0  ...
# 4  100020        1     7     1    45     1       6     2.0      8  10.0  ...
# 5  100035        1     7     1    62     1       2     0.0      8  11.0  ...
# 6  100037        1     4     2    27     6       4     1.0      8   NaN  ...
# 7  100038        1     7     2    28     1       6     4.0      8  10.0  ...
# 8  100046        1     7     2    51     6       1     NaN     11   NaN  ...
# 9  100049        1     5     2    44     1       5     3.0     12  14.0  ...
#
#    CitizenadjBA  CitizenadjIn  CitizenadjPa  CitizenadjBang  Citizenadjtotal  \
# 0        138.16        304.94        359.52           74.16           919.58
# 1         34.54         26.07        212.52            3.09           295.48
# 2         34.54         26.07        212.52            3.09           295.48
# 3         34.54         26.07        212.52            3.09           295.48
# 4        138.16        304.94        359.52           74.16           919.58
# 5        138.16        304.94        359.52           74.16           919.58
# 6         17.27         21.33         68.88           20.60           165.53
# 7        171.13         32.39        108.36           22.66           588.13
# 8        259.05         10.27          0.00            8.24           593.21
# 9         17.27          9.48          7.56            0.00            99.58
#
#     Popdensity  Intno  Inteth  Intsex  PSUIdentifier
# 0  5828.000000  69073       4       1           1148
# 1  4977.419355  62138       7       1           1149
# 2  4977.419355  62138       7       1           1149
# 3  4977.419355  62138       7       1           1149
# 4  5828.000000  69073       4       1           1148
# 5  5828.000000  69073       4       1           1148
# 6  4558.823529  70619       5       2           1443
# 7  7715.789474  71417       6       2           1197
# 8  7269.565217  69192       7       2           1103
# 9  6151.851852  71570       7       2           1362
#
# [10 rows x 637 columns]

# %%
#Creating a clean dataframe
#Variables to keep zqinc (Annual Household Income), bq9_1 (Party Identification)
#and zq101 (Ethnicity)
clean_df = df[["zqinc", "bq9_1", "zq101"]].copy()

#Renaming variables for clarity
clean_df.columns = ["annual_income", "political_party", "ethnicity"]

# %%
#Cleaning the dataset
clean_df.head(10)
# Out:
#    annual_income  political_party  ethnicity
# 0             13                2          8
# 1              4                2          3
# 2              4                1          8
# 3              4                2          8
# 4              3                2          8
# 5              7                3          8
# 6              4                2          8
# 7             -2                2          8
# 8             -2                2         11
# 9              7                1         12
